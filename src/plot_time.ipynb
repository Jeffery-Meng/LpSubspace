# %%
l1_times = {25: 8.31, 32: 8.93,  64:10.88,  96:12.87, 128: 15.34, 768: 48.54, 960: 94.19, 1369: 79.96, 4096: 810.9}
l2_times = {96: 16.94e-3, 128: 17.87e-3, 256: 18.87e-3, 784: 19.97e-3, 960: 20.60e-3, 1369: 21.91e-3, 4096: 32.14e-3}

data = [(l1_times.keys(), l1_times.values()), (l2_times.keys(), l2_times.values())]
from oniakPlot.line_plot import plot_result
import os
os.getcwd()
# Out:
# '/media/gtnetuser/SSD_2TB_BEST/LpSubspace/src'

# %%
plot_result(data, line_names=[r"$L_1$-P2S", r"$L_2$-P2S"], xlabel="Ambient dimension $d$", ylabel="Time (ms) per Instance", 
            figtitle="", logx=True, logy=True, legend_pos="upper left", grid=True, 
            savepath="/media/mydrive_2/Dropbox (GaTech)/lpsubspace/Lp Subspace/figures/time_comp.pdf")
# Out:
# <Axes: xlabel='Ambient dimension $d$', ylabel='Time (ms) per Instance'>
